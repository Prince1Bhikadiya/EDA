# %% [markdown]
# <a href="https://colab.research.google.com/github/Prince1Bhikadiya/EDA/blob/main/Avatar2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pygit2==1.12.2
# %cd /content
# !git clone https://github.com/Prince1Bhikadiya/imagegen.git
# %cd /content/imagegen
# !python entry_with_update.py --share
# Out:
# ...
# ERROR: Operation cancelled by user
# /content
# Cloning into 'imagegen'...
# remote: Enumerating objects: 613, done.
# remote: Counting objects: 100% (613/613), done.
# remote: Compressing objects: 100% (560/560), done.
# remote: Total 613 (delta 36), reused 613 (delta 36), pack-reused 0
# Receiving objects: 100% (613/613), 9.88 MiB | 31.22 MiB/s, done.
# Resolving deltas: 100% (36/36), done.
# /content/imagegen
# Update failed.
# No module named 'pygit2'
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share']
# Python 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# Fooocus version: 2.1.865
# Error checking version for torchsde: No package metadata was found for torchsde
# Installing requirements
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/xlvaeapp.pth" to /content/imagegen/models/vae_approx/xlvaeapp.pth
#
# 100% 209k/209k [00:00<00:00, 13.5MB/s]
# ...
